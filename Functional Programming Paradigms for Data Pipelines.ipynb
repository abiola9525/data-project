# %%
import pandas as pd

# %%
titanic = pd.read_csv('tested_csv.csv')
titanic.head()
# Out:
#    Unnamed: 0  PassengerId  Survived  Pclass
# 0           0        892.0       0.0     3.0  \
# 1           1        893.0       1.0     3.0
# 2           2        894.0       0.0     2.0
# 3           3        895.0       0.0     3.0
# 4           4        896.0       1.0     3.0
#
#                                            Name     Sex   Age  SibSp  Parch
# 0                              Kelly, Mr. James    male  34.5    0.0    0.0  \
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0    1.0    0.0
# 2                     Myles, Mr. Thomas Francis    male  62.0    0.0    0.0
# 3                              Wirz, Mr. Albert    male  27.0    0.0    0.0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0    1.0    1.0
#
#       Ticket     Fare Cabin Embarked
# 0   330911.0   7.8292   NaN        Q
# 1   363272.0   7.0000   NaN        S
# 2   240276.0   9.6875   NaN        Q
# 3   315154.0   8.6625   NaN        S
# 4  3101298.0  12.2875   NaN        S

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 13 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Unnamed: 0   418 non-null    int64
#  1   PassengerId  418 non-null    float64
#  2   Survived     418 non-null    float64
#  3   Pclass       418 non-null    float64
#  4   Name         418 non-null    object
#  5   Sex          418 non-null    object
#  6   Age          332 non-null    float64
#  7   SibSp        418 non-null    float64
#  8   Parch        418 non-null    float64
#  9   Ticket       418 non-null    object
#  10  Fare         417 non-null    float64
#  11  Cabin        91 non-null     object
#  12  Embarked     418 non-null    object
# dtypes: float64(7), int64(1), object(5)
# memory usage: 42.6+ KB

# %%
male_survivors = titanic[(titanic.Sex ==  'female') & (titanic.Survived == 1)]
male_survivors
# Out:
#      Unnamed: 0  PassengerId  Survived  Pclass
# 1             1        893.0       1.0     3.0  \
# 4             4        896.0       1.0     3.0
# 6             6        898.0       1.0     3.0
# 8             8        900.0       1.0     3.0
# 12           12        904.0       1.0     1.0
# ..          ...          ...       ...     ...
# 409         409       1301.0       1.0     3.0
# 410         410       1302.0       1.0     3.0
# 411         411       1303.0       1.0     1.0
# 412         412       1304.0       1.0     3.0
# 414         414       1306.0       1.0     1.0
#
#                                                 Name     Sex   Age  SibSp
# 1                   Wilkes, Mrs. James (Ellen Needs)  female  47.0    1.0  \
# 4       Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0    1.0
# 6                               Connolly, Miss. Kate  female  30.0    0.0
# 8          Abrahim, Mrs. Joseph (Sophie Halaut Easu)  female  18.0    0.0
# ...

# %%
ages = male_survivors['Age'].tolist()
ages
# Out:
# [47.0,
#  22.0,
#  30.0,
#  18.0,
#  23.0,
#  47.0,
#  24.0,
#  27.0,
#  45.0,
#  nan,
#  48.0,
#  22.0,
#  33.0,
#  nan,
#  nan,
#  21.0,
#  30.0,
#  45.0,
#  60.0,
#  36.0,
#  20.0,
#  28.0,
#  36.0,
#  22.0,
#  nan,
#  18.0,
#  60.0,
#  24.0,
#  29.0,
#  35.0,
#  55.0,
#  24.0,
#  27.0,
#  18.0,
#  nan,
#  22.0,
#  27.0,
#  76.0,
#  20.0,
#  43.0,
#  16.0,
#  nan,
#  36.0,
#  18.5,
#  63.0,
#  1.0,
#  29.0,
#  12.0,
#  35.0,
#  17.0,
#  nan,
#  nan,
#  23.0,
#  10.0,
#  33.0,
#  23.0,
#  36.0,
#  29.0,
#  23.0,
#  26.0,
#  nan,
#  26.0,
#  26.0,
#  nan,
#  22.0,
#  15.0,
#  20.0,
#  36.0,
#  64.0,
#  18.0,
#  27.0,
#  21.0,
#  nan,
#  18.0,
#  nan,
#  nan,
#  8.0,
#  35.0,
#  33.0,
#  60.0,
#  38.0,
#  nan,
#  50.0,
#  30.0,
#  22.0,
#  53.0,
#  nan,
#  nan,
#  21.0,
#  18.0,
#  48.0,
#  55.0,
#  45.0,
#  22.0,
#  29.0,
#  nan,
#  0.92,
#  19.0,
#  29.0,
#  1.0,
#  nan,
#  26.0,
#  nan,
#  20.0,
#  23.0,
#  nan,
#  9.0,
#  2.0,
#  30.0,
#  1.0,
#  nan,
#  64.0,
#  45.0,
#  37.0,
# ...

# %%
from functools import reduce

# Load the Titanic dataset

# Filter the dataset to include only male passengers who survived
filtered_titanic = titanic[(titanic.Sex == 'male') & (titanic.Survived == 0)]

if len(filtered_titanic) > 0:
    # Use function composition to extract the age of each passenger and calculate the average age
    average_age = reduce(lambda acc, x: acc + x, map(lambda x: x['Age'], filtered_titanic.to_dict('records'))) / len(filtered_titanic)
    print(average_age, "this")
else:
    average_age = None
    print(average_age, "Hello")
# Out:
# nan this

# %%
data['Embarked'].nunique()
# Out:
# 3

# %%
import pandas as pd

# Load the dataset
data = pd.read_csv('tested_csv.csv')

# Apply a function to a column
# data['Age'] = data['Age'].apply(lambda x: x + 1)
data = data.assign(Total_Amount=data['Fare'] + data['Pclass'])
data
# Out:
#      Unnamed: 0  PassengerId  Survived  Pclass
# 0             0        892.0       0.0     3.0  \
# 1             1        893.0       1.0     3.0
# 2             2        894.0       0.0     2.0
# 3             3        895.0       0.0     3.0
# 4             4        896.0       1.0     3.0
# ..          ...          ...       ...     ...
# 413         413       1305.0       0.0     3.0
# 414         414       1306.0       1.0     1.0
# 415         415       1307.0       0.0     3.0
# 416         416       1308.0       0.0     3.0
# 417         417       1309.0       0.0     3.0
#
#                                              Name     Sex   Age  SibSp  Parch
# 0                                Kelly, Mr. James    male  34.5    0.0    0.0  \
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0    1.0    0.0
# 2                       Myles, Mr. Thomas Francis    male  62.0    0.0    0.0
# 3                                Wirz, Mr. Albert    male  27.0    0.0    0.0
# ...

# %%
grouped_data = data.groupby('Sex')['Age'].agg('mean')
grouped_data.plot(kind='pie')
# Out:
# <Axes: ylabel='Age'>

# %%
grouped_data = data.groupby(['Sex', 'Embarked'])['Age'].agg('mean')
grouped_data.plot(kind='pie')
# Out:
# <Axes: ylabel='Age'>
